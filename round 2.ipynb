# %%
import requests
from bs4 import BeautifulSoup
headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
}

url = "https://www.reserveamerica.com/campgroundDirectory.do"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
# print(soup.prettify())"

# %%
def getCGs(state_url):
    state_req = requests.get(state_url, headers)
    state_soup = BeautifulSoup(state_req.content, 'html.parser')
    cgs = state_soup.find_all('a', href=True)
#     amens = state_soup.find_all('div', {'class':'td amenitiesicons'})
    print(amens)
    cg_urls = []
    for c in cgs:
        if 'overview' in c['href']:
            if (raurl + c['href']) not in cg_urls:
                cg_urls.append(raurl + c['href'])
                print(raurl + c['href'], amens[idx])
    if len(cg_urls) < 25:
        pass
    else:
        np_url = state_url + "&startIdx=25"
        np_req = requests.get(np_url, headers)
        np_soup = BeautifulSoup(np_req.content, 'html.parser')
        np_cgs = np_soup.find_all('a', href=True)
        for npc in np_cgs:
            if 'overview' in npc['href']:
                if (raurl + npc['href']) not in cg_urls:
                    cg_urls.append(raurl + npc['href'])
    if len(cg_urls) < 50:
        pass
    else:
        np_url = state_url + "&startIdx=50"
        np_req = requests.get(np_url, headers)
        np_soup = BeautifulSoup(np_req.content, 'html.parser')
        np_cgs = np_soup.find_all('a', href=True)
        for npc in np_cgs:
            if 'overview' in npc['href']:
                if (raurl + npc['href']) not in cg_urls:
                    cg_urls.append(raurl + npc['href'])
    for cg in cg_urls:
        print(cg)

# %%
anchors = soup.find_all('a', href=True)
raurl = "https://www.reserveamerica.com"
for a in anchors:
    if "/camping/" in raurl + a['href']:
        getCGs(raurl + a['href'])
# Out:
# [<div class="td amenitiesicons">
# <img alt="Electric Hookup - no" height="22" src="/images/2013/icon_amps_no.gif" title="Electric Hookup - no" width="22"/>
# <img alt="Full Hookup - no" height="22" src="/images/2013/icon_fullhookup_no.gif" title="Full Hookup - no" width="22"/><br/>
# <img alt="Pets Allowed" height="22" src="/images/2013/icon_pets.gif" title="Pets Allowed" width="22"/>
# <img alt="Near Water" height="22" src="/images/2013/icon_waterfront.gif" title="Near Water" width="22"/></div>, <div class="td amenitiesicons">
# <img alt="Electric Hookup - no" height="22" src="/images/2013/icon_amps_no.gif" title="Electric Hookup - no" width="22"/>
# <img alt="Full Hookup - no" height="22" src="/images/2013/icon_fullhookup_no.gif" title="Full Hookup - no" width="22"/><br/>
# <img alt="Pets Allowed" height="22" src="/images/2013/icon_pets.gif" title="Pets Allowed" width="22"/>
# ...
